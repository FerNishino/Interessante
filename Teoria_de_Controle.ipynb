# %% [markdown]
# <a href="https://colab.research.google.com/github/FerNishino/Interessante/blob/main/Teoria_de_Controle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A biblioteca CONTROL foi utilizada para simular resposta ao degrau, diagrama de bode e diagrama do Lugar das Raízes de sistemas lineares invariantes no tempo.

# %%
# !pip install control
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.8/432.8 kB 11.7 MB/s eta 0:00:00
# ...

# %%
from control import *
import matplotlib.pyplot as plt

# %%
g=tf([1], [1,1,1])

# %%
t,y =step_response(g)

# %%
plt.plot(t,y)
plt.grid()
plt.xlabel('Tempo [s]')
plt.ylabel('y(t) [Volts]')
# Out:
# Text(0, 0.5, 'y(t) [Volts]')

# %%
A=[[0,1], [-1,-1]]
B=[[0], [1]]
C=[1,0]
D=[0]

# %%
sys=ss(A,B,C,D)

# %%
g=tf([1],[1,0.5,1]);
bode_plot(g, dB=True);

# %%
g=tf(1,[1,2,3,4,0])

# %%
rlocus(g)
# Out:
# (array([[-1.65062919e+00 +0.j        , -1.74685404e-01 -1.54686889j,
#          -1.74685404e-01 +1.54686889j,  0.00000000e+00 +0.j        ],
#         [-1.58908120e+00 +0.j        , -1.46998131e-01 -1.51361601j,
#          -1.46998131e-01 +1.51361601j, -1.16922542e-01 +0.j        ],
#         [-1.51527228e+00 +0.j        , -1.13875475e-01 -1.48121949j,
#          -1.13875475e-01 +1.48121949j, -2.56976775e-01 +0.j        ],
#         [-1.42063021e+00 +0.j        , -7.49252719e-02 -1.45153446j,
#          -7.49252719e-02 +1.45153446j, -4.29519241e-01 +0.j        ],
#         [-1.27820520e+00 +0.j        , -3.07958348e-02 -1.42680999j,
#          -3.07958348e-02 +1.42680999j, -6.60203129e-01 +0.j        ],
#         [-1.27820520e+00 +0.j        , -3.07958348e-02 -1.42680999j,
#          -3.07958348e-02 +1.42680999j, -6.60203129e-01 +0.j        ],
#         [-1.00000003e+00 +0.j        , -5.55111512e-16 -1.41421356j,
# ...
